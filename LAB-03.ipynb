# %% [markdown]
# PART A: DATA LOADING AND BASIC UNDERSTANDING

# %%
#1. Import the required Python libraries (pandas, numpy, matplotlib, seaborn).
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#2. Load the dataset into a pandas DataFrame.
df = pd.read_csv("Customer Purchasing Behaviors.csv")

#3.Display the number of rows and columns in the dataset.
print(df.shape)
print("Number of rows: ",df.shape[0])
print("Number of columns: ",df.shape[1])

#4.Print the column names of the dataset.
print(df.columns)

#5.Display the first 5 rows of the dataset.
df.head()
# Out:
# (238, 7)
# Number of rows:  238
# Number of columns:  7
# Index(['user_id', 'age', 'annual_income', 'purchase_amount', 'loyalty_score',
#        'region', 'purchase_frequency'],
#       dtype='object')
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
# 4        5   29          47000              220            4.8  North
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22
# 3                  10
# 4                  13

# %% [markdown]
# Pandas -> data handling and Data frames
# numpy -> for numerical operations
# matplotlib -> basic plotting
# seaborn -> advanced statistical visualizations
#
# df.shape returns a tuple consisting of (no of rows,no of columns)

# %% [markdown]
# PART B: DATA TYPES AND MISSING VALUES

# %%
#6.Check the data type of each column.
print(df.info())

#7.Identify the number of missing values in each column.
print(df.isnull().sum())

#8.Fill missing values in numerical columns using the mean.


#9.Fill missing values in categorical columns using the mode

      
#10.Verify that there are no missing values remaining.
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             238 non-null    int64
#  1   age                 238 non-null    int64
#  2   annual_income       238 non-null    int64
#  3   purchase_amount     238 non-null    int64
#  4   loyalty_score       238 non-null    float64
#  5   region              238 non-null    object
#  6   purchase_frequency  238 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 13.1+ KB
# None
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# ...

# %% [markdown]
# df.isnull().sum() returns the number of missing values per column

# %% [markdown]
# PART C: DESCRIPTIVE STATISTICS

# %%
#11.Calculate the mean for all numerical columns.
print("\nThe mean values of the columns are: ")
print(df.mean(numeric_only=True))

# 12.Calculate the median for all numerical columns.
print("\nThe median values of the columns are: ")
print(df.median(numeric_only=True))

# 13.Calculate the standard deviation for all numerical columns.
print("\nThe Standard Deviation: ")
print(df.std(numeric_only=True))
      
# 14.Find the minimum and maximum values for numerical columns.
print(df.agg(['min','max']))

# 15.Generate a summary using describe()
print(df.describe())
# Out:
# The mean values of the columns are:
# user_id                 119.500000
# age                      38.676471
# annual_income         57407.563025
# purchase_amount         425.630252
# loyalty_score             6.794118
# purchase_frequency       19.798319
# dtype: float64
#
# The median values of the columns are:
# user_id                 119.5
# age                      39.0
# annual_income         59000.0
# purchase_amount         440.0
# loyalty_score             7.0
# purchase_frequency       20.0
# dtype: float64
#
# The Standard Deviation:
# user_id                  68.848868
# age                       9.351118
# annual_income         11403.875717
# purchase_amount         140.052062
# loyalty_score             1.899047
# purchase_frequency        4.562884
# dtype: float64
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# min        1   22          30000              150            3.0   East
# ...

# %% [markdown]
# #Mean : the average value of a datset.
# -> represents the central value of data
#
# #Median : middle value of a dataset.
#
# #Mode : most frequently occurred value in a dataset.
#
# #std : the stadard deviation measures how much the values in a dataset deviate from the mean
#
# #agg(): The agg() function in pandas is used to apply one or more statistical operations to a DataFrame.

# %% [markdown]
# PART D: BASIC ANALYSIS AND VISUALISATION

# %%
# #16.Create a histogram for the purchase amount column.
plt.figure()
plt.hist(df['purchase_amount'], bins=10)
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.title('Histogram of Purchase Amount')
plt.show()

# 17.Create a bar chart showing the count of customers by product category.
#since we dont have a product category we use the region attribute
region_counts = df['region'].value_counts()

plt.figure()
plt.bar(region_counts.index, region_counts.values)
plt.xlabel('Region')
plt.ylabel('Number of Customers')
plt.title('Customer Count by Region')
plt.show()

# 18.Create a box plot for the purchase amount column.
plt.figure()
plt.boxplot(df['purchase_amount'])
plt.ylabel('Purchase Amount')
plt.title('Box Plot of Purchase Amount')
plt.show()

# 19.Create a scatter plot between age and purchase amount.
plt.figure()
plt.scatter(df['age'], df['purchase_amount'])
plt.xlabel('Age')
plt.ylabel('Purchase Amount')
plt.title('Age vs Purchase Amount')
plt.show()

# 20.Display a correlation heatmap for numerical columns.
corr = df.corr(numeric_only=True)

plt.figure()
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ANALYSIS PART:
# Customer Demographic Analysis :
#     lets check which age group spends more
#     Which region has more customers
#     Regional differences in income and spending

# %%
plt.figure()
plt.hist(df['age'],bins=8)
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.title('Age Distribution of Customers')
plt.show()

# %% [markdown]
# Summary;
# From the above histogram we can conclude that a higher concentration of customers are around the age group 40-45 compared to other groups

# %%
df['age'].describe()
# Out:
# count    238.000000
# mean      38.676471
# std        9.351118
# min       22.000000
# 25%       31.000000
# 50%       39.000000
# 75%       46.750000
# max       55.000000
# Name: age, dtype: float64

# %%
#customer distribution by region
plt.figure()
df['region'].value_counts().plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Number of customers')
plt.title('Customer Distribution by Region')
plt.show()

# %% [markdown]
# Summary:
# The bar chart shows the number of customers in each region. Three of the regions have almost the same concentration of customers(North ,South, West), while customers from the east are less frequent.

# %%
#Age spread of customers in each region
plt.figure()
sns.boxplot(x='region', y='age', data=df)
plt.xlabel('Region')
plt.ylabel('Age')
plt.title('Age Distribution Across Regions')
plt.show()

# %% [markdown]
# Summary;
# West region has the highest median age, indicating relatively older customers.
#
# North and East regions have lower median ages, suggesting younger customer bases.
#
# South falls in between.

# %%
plt.hist(df['purchase_amount'], bins=10)
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.title('Purchase Amount Distribution')
plt.show()

# %%
df['purchase_amount'].describe()
# Out:
# count    238.000000
# mean     425.630252
# std      140.052062
# min      150.000000
# 25%      320.000000
# 50%      440.000000
# 75%      527.500000
# max      640.000000
# Name: purchase_amount, dtype: float64

# %%
plt.boxplot(df['purchase_amount'])
plt.ylabel('Purchase Amount')
plt.title('Box Plot of Purchase Amount')
plt.show()

# %% [markdown]
# Box plot : used for median,spread and outliers
# it identifies variability and possible outliers in purchase amounts.

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='viridis')
plt.title('Correlation Heatmap')
plt.show()
